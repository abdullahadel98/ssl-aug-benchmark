# %% [markdown]
# ### benchmark training

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
! git clone --branch kaggle --single-branch https://github.com/abdullahadel98/ssl-aug-benchmark.git

# %%
os.chdir('/kaggle/working/ssl-aug-benchmark')

# %%
! git pull

# %%
# Set environment variables to disable wandb interactive prompts
import os
os.environ['WANDB_MODE'] = 'disabled'  # Disable wandb completely
# Alternative: os.environ['WANDB_SILENT'] = 'true'  # Or use this to keep wandb but suppress prompts

# Run the experiment
! bash soloLearn_exp.sh
# Out:
# Looking in indexes: https://pypi.org/simple, https://developer.download.nvidia.com/compute/redist
# Processing /kaggle/working/ssl-aug-benchmark/learning/solo-learn
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for solo-learn: filename=solo_learn-1.0.6-py3-none-any.whl size=246776 sha256=8b7a5f47c61ad347fc2c2e54c18990720c60d3d58c24ac8673231ae0e8be8789
#   Stored in directory: /root/.cache/pip/wheels/43/a0/ff/9880a25d2e534379d13ffd96bc8d85094a45dfac7e27edbf8a
# Successfully built solo-learn
# ...
#   Attempting uninstall: solo-learn
#     Found existing installation: solo-learn 1.0.6
#     Uninstalling solo-learn-1.0.6:
#       Successfully uninstalled solo-learn-1.0.6
# ...
# 2025-11-05 23:56:09.898163: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...
